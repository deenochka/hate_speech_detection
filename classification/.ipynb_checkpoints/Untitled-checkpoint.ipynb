# %% [markdown]
# ### imports

# %%
import pandas as pd
from twython import Twython
import time

# %%
#!pip install twython --user

# %% [markdown]
# ### Get tweets by id:

# %%
#[CONSUMER_API_KEYS]
consumer_key='HCytTs147TXl1XOuDM7lHumhF'
consumer_secret='8OjtpLjgmEj9zoOH7XCa1SdlxQwCszCYsefrStgqOX1ywBRb9J'


#[ACCESS_TOKES]
access_token='1072242787398094850-JSLYGK9xhucosjI9CflWqTAJ1KaIH2'
access_token_secret='Lr8gqLfwZIyC1DLSZzw4eClPfWN9mV3TNmMc4a33sgOUW'

# %%
twitter = Twython(consumer_key, consumer_secret, access_token, access_token_secret)

# %%
def get_tweet_text_by_id(id):
#     try:
    time.sleep(1)
    tweet = twitter.show_status(id=id)
    return tweet['text']
#     except:
#         return ''

# %%
get_tweet_text_by_id(id=572341498827522049)
# Out:
# "Drasko they didn't cook half a bird you idiot #mkr"

# %%
df = pd.read_csv('data/NAACL_SRW_2016.csv')

# %%
df.columns = ['id', 'label']

# %%
df = df.mask(df.eq('none')).dropna()

# %%
df['text'] = None

# %%
df.head()
# Out:
#                    id   label  text
# 0  572341498827522049  racism  None
# 1  572340476503724032  racism  None
# 2  572334712804384768  racism  None
# 3  572332655397629952  racism  None
# 4  575949086055997440  racism  None

# %%
df.label.value_counts()
# Out:
# sexism    3378
# racism    1969
# Name: label, dtype: int64

# %%
len(df)
# Out:
# 5347

# %%
# df['text'] = df['id'].apply(get_tweet_text_by_id)

# %%
# df2 = df.head(100)

# %%
# df2['text'] = df2['id'].apply(get_tweet_text_by_id)

# %%
for index, row in df.iterrows():
#     row[ (row['label'], row['id'])
    if row['text']:
        continue
    time.sleep(1)
    text = get_tweet_text_by_id(id=row['id'])
#     print(text)
    df.set_value(index,'text',text)
# Out:
# ---------------------------------------------------------------------------
# TwythonError                              Traceback (most recent call last)
# <ipython-input-140-df5bf21b5368> in <module>
#       4         continue
#       5     time.sleep(1)
# ----> 6     text = get_tweet_text_by_id(id=row['id'])
#       7 #     print(text)
#       8     df.set_value(index,'text',text)
#
# <ipython-input-92-bd95d824abfa> in get_tweet_text_by_id(id)
#       2 #     try:
#       3     time.sleep(1)
# ----> 4     tweet = twitter.show_status(id=id)
#       5     return tweet['text']
#       6 #     except:
#
# ~/.local/lib/python3.7/site-packages/twython/endpoints.py in show_status(self, **params)
#      92
#      93         """
# ---> 94         return self.get('statuses/show/%s' % params.get('id'), params=params)
#      95
#      96     def lookup_status(self, **params):
#
# ~/.local/lib/python3.7/site-packages/twython/api.py in get(self, endpoint, params, version)
# ...

# %%
df.loc[df['text'] != None].text.count()

# %%
df.head(50)
# Out:
#                     id   label  \
# 0   572341498827522049  racism
# 1   572340476503724032  racism
# 2   572334712804384768  racism
# 3   572332655397629952  racism
# 4   575949086055997440  racism
# 5   551659627872415744  racism
# 6   551763146877452288  racism
# 7   551768543277355009  racism
# 8   551769061055811584  racism
# 9   551769698917167104  racism
# 10  551779988567891969  racism
# 11  551783732466577408  racism
# 12  551787027725705216  racism
# 13  551787273256050688  racism
# 14  551787717168619521  racism
# 15  551796768623435776  racism
# 16  551797843472556032  racism
# 17  551798472827883520  racism
# 18  551799120080293888  racism
# 19  551804052606967810  racism
# 20  551807282153934848  racism
# 21  551812016768172032  racism
# 22  551935344644349952  racism
# 23  551935446427504640  racism
# 24  551984700764332032  racism
# 25  552131027590586368  racism
# 26  552132765592727553  racism
# 27  552133306553073665  racism
# 28  552178267927883776  racism
# ...

# %%
df.head(50).id.tolist()
# Out:
# [572341498827522049,
#  572340476503724032,
#  572334712804384768,
#  572332655397629952,
#  575949086055997440,
#  551659627872415744,
#  551763146877452288,
#  551768543277355009,
#  551769061055811584,
#  551769698917167104,
#  551779988567891969,
#  551783732466577408,
#  551787027725705216,
#  551787273256050688,
#  551787717168619521,
#  551796768623435776,
#  551797843472556032,
#  551798472827883520,
#  551799120080293888,
#  551804052606967810,
#  551807282153934848,
#  551812016768172032,
#  551935344644349952,
#  551935446427504640,
#  551984700764332032,
#  552131027590586368,
#  552132765592727553,
#  552133306553073665,
#  552178267927883776,
#  552242912487305218,
#  552243885196734464,
#  552245992721252352,
#  552246388025982976,
#  552247283438587905,
#  552247950039326720,
#  552248563330482176,
#  552252662381432832,
#  552253146970337280,
#  552253495328247809,
#  552253987701788672,
#  552254351754817536,
#  552254776218365953,
#  552255235863756800,
# ...
